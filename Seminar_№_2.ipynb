# %% [markdown]
# <!--<div align="center">Семинар № 2-->
#
# <div align="center"><font color=#4682B4 size=4 face=
#                           "arial black"><em><strong>Семинар № 2</strong></em></font></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>Задание 1 . </b>Сделайте приоритезацию гипотез из предыдущего урока с помощью ICE.
# </em></div>

# %% [markdown]
# _**1. Гипотеза:**_<br>
# Если добавить к карточке блюда "вкусное" описание ингридиентов,
# то стоимость привлечения пользователей и число посещений увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **CAC** и **Total visit**.
# ***

# %% [markdown]
# _**2. Гипотеза:**_<br>
# Если дать возможность клиенту оплачивать наличными и/или при получении заказа, то конверсия в покупках увеличится, а кол-во отказов уменьшится;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **CR** и **Bounce Rate** .
# ***

# %% [markdown]
# _**3. Гипотеза:**_<br>
# Если предусмотреть скидки  за последующие заказы, то число посещений и процент клиентов, которые возвращаются для совершения повторных покупок увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **Total visit** и **CRR**.
# ***

# %% [markdown]
# _**4. Гипотеза:**_<br>
# Если предусмотреть скидки для заказа комплексного обеда, то месячная возобновляемая выручка и  число посещений увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **MRR** и **Total visit**.
# ***

# %% [markdown]
# _**5. Гипотеза:**_<br>
# Если  разместить опросник, с указанием 3-4 причин выхода с сайта, то процент клиентов, которые возвращаются для совершения повторных покупок и конверсия в покупках увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На пользователях, не совершивших покупки;<br>
#
# _**Метрики:**_<br>
# **CRR** и **CR**.
# ***

# %% [markdown]
# _**6. Гипотеза:**_<br>
# Если внедрить интересную анимацию при покупке, то стоимость привлечения клиента и средний чек увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **CAC** и **AOV**.
# ***

# %% [markdown]
# _**7. Гипотеза:**_<br>
# Если разместить на сайте страницу-репортаж из кухни и показать процесс готовки, то время, проведенное на сайте увеличится, а количество отказов уменьшится;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **Time Spent on Site** и **Bounce Rate**.
# ***

# %% [markdown]
# _**8. Гипотеза:**_<br>
# Если разместить на карточке блюда ссылку на отзывы клиентов о нём, то время, проведенное на сайте увеличится, а количество отказов уменьшится;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **Time Spent on Site** и **Bounce Rate**.
# ***

# %% [markdown]
# _**9. Гипотеза:**_<br>
# Если регулярно рассылать клиентам по почте и в СМС акции  и новые блюда, то месячная возобновляемая выручка и  число посещений увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - клиенты, подключённые к рассылке;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **MRR** и **Total visit**.
# ***

# %% [markdown]
# _**10. Гипотеза:**_<br>
# Если сделать регулярные акции-скидки на разные блюда, то месячная возобновляемая выручка и средний чек увеличатся;<br>
#
# _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - дать доступ к сайту с изменениями;<br>
#
# _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
# _**Метрики:**_<br>
# **MRR** и **AOV**.
# ***

# %% [markdown]
# <h3 align="center"><em>
#    Приоритизация гипотез:</em>
# </h3>
#
# |&nbsp;&nbsp;_**№**_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|_**I**<br> &nbsp;&nbsp;(влияние)_&nbsp;&nbsp;&nbsp;|_**C**<br> (уверенность)_&nbsp;|_**E**<br> (легкость реализации)_|&nbsp;&nbsp;&nbsp; _**Score**_ &nbsp;&nbsp;&nbsp;|
# |:---|:---:|:---:|:---:|:---:|
# |_**1**_|6     |7     |4     |168|
# |_**2**_|5     |6     |2     |60|
# |_**3**_|7     |7     |8     |392|
# |_**4**_|7     |8     |6     |336|
# |_**5**_|4     |3     |5     |60|
# |_**6**_|3     |2     |8     |48|
# |_**7**_|6     |5     |1     |30|
# |_**8**_|8     |6     |3     |144|
# |_**9**_|7     |8     |5     |280|
# |_**10**_|7     |7     |7     |343|

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>Задание 2 . </b>Составьте шаблон дизайна эксперимента для гипотезы,<br>
#     которая набрала больше всего баллов в практическом задании предыдущего урока.
# </em></div>

# %% [markdown]
# _**3-я гипотеза**_ набрала больше всего баллов (**392**):<br>
# 1. Если предусмотреть скидки  за последующие заказы, то число посещений и процент клиентов, которые возвращаются для совершения повторных покупок увеличатся;<br>
#
#
# 2. _**Что делаем в каждой из групп:**_<br>
# Контрольная - без изменений, тестовая - получает скидку при следующей покупке;<br>
#
#
# 3. _**На каких пользователях тестируем:**_<br>
# На всех пользователях;<br>
#
#
# 4. _**Метрики:**_<br>
#  **Total visit** и **CRR**;<br>
#
#
# 5. _**Ожидаемый эффект:**_<br>
# Ожидаем существенное увеличение значений метрик минимум на 10%.
#
#
# 6. _**План действий в зависимости от результатов эксперимента:**_<br>
# В случае успешности - применяем изменения для всех пользователей,
# при неудаче - оставляем прежнюю версию.
# ***
